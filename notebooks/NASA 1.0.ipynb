# %%
data = pd.read_csv("./nasa_exoplanets.csv")
data.head()
# Out:
#    row                  name  light_years_from_earth     planet_mass  \
# 0    0  11 Comae Berenices b                   305.0   19.4 Jupiters
# 1    1    11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2    2       14 Andromedae b                   247.0    4.8 Jupiters
# 3    3         14 Herculis b                    59.0   4.66 Jupiters
# 4    4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar_magnitude  discovery_date planet_type   planet_radius  \
# 0              4.740            2007   Gas Giant  1.08 x Jupiter
# 1              5.016            2009   Gas Giant  1.09 x Jupiter
# 2              5.227            2008   Gas Giant  1.15 x Jupiter
# 3              6.610            2002   Gas Giant  1.15 x Jupiter
# 4              6.250            1996   Gas Giant   1.2 x Jupiter
#
#   orbital_radius orbital_period eccentricity solar_system_name  \
# 0        1.29 AU       326 days         0.23            11 Com
# 1        1.53 AU      1.4 years         0.08            11 UMi
# 2        0.83 AU     185.8 days            0            14 And
# 3        2.93 AU      4.9 years         0.37            14 Her
# 4        1.66 AU      2.2 years         0.68          16 Cyg B
#
#   planet_discovery_method  planet_orbital_inclination  planet_density  \
# 0         Radial Velocity                         NaN             NaN
# 1         Radial Velocity                         NaN             NaN
# 2         Radial Velocity                         NaN             NaN
# 3         Radial Velocity                         NaN             NaN
# 4         Radial Velocity                         NaN             NaN
#
#   right_ascension   declination  host_temperature  host_mass  host_radius
# 0    12h20m43.03s  +17d47m34.3s            4742.0       2.70        19.00
# 1    15h17m05.89s  +71d49m26.0s            4213.0       2.78        29.79
# 2    23h31m17.42s  +39d14m10.3s            4813.0       2.20        11.00
# 3    16h10m24.31s  +43d49m03.5s            5338.0       0.90         0.93
# 4    19h41m51.97s  +50d31m03.1s            5750.0       1.08         1.13

# %%
import pandas as pd
import numpy as np
import calendar
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import datetime
import re
pd.options.display.max_columns = None

# %%
from collections import Counter
from fuzzywuzzy import process, fuzz
import pickle
# Out:
# C:\Users\pedro\anaconda3\envs\ironhack\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
data.shape , data.size

# %%
data.columns

# %%
new_columns = [i.replace("_"," " ) for i in data.columns]
data.columns = new_columns
data.head(5)
# Out:
#    row                  name  light years from earth     planet mass  \
# 0    0  11 Comae Berenices b                   305.0   19.4 Jupiters
# 1    1    11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2    2       14 Andromedae b                   247.0    4.8 Jupiters
# 3    3         14 Herculis b                    59.0   4.66 Jupiters
# 4    4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar magnitude  discovery date planet type   planet radius  \
# 0              4.740            2007   Gas Giant  1.08 x Jupiter
# 1              5.016            2009   Gas Giant  1.09 x Jupiter
# 2              5.227            2008   Gas Giant  1.15 x Jupiter
# 3              6.610            2002   Gas Giant  1.15 x Jupiter
# 4              6.250            1996   Gas Giant   1.2 x Jupiter
#
#   orbital radius orbital period eccentricity solar system name  \
# 0        1.29 AU       326 days         0.23            11 Com
# 1        1.53 AU      1.4 years         0.08            11 UMi
# 2        0.83 AU     185.8 days            0            14 And
# 3        2.93 AU      4.9 years         0.37            14 Her
# 4        1.66 AU      2.2 years         0.68          16 Cyg B
#
#   planet discovery method  planet orbital inclination  planet density  \
# 0         Radial Velocity                         NaN             NaN
# 1         Radial Velocity                         NaN             NaN
# 2         Radial Velocity                         NaN             NaN
# 3         Radial Velocity                         NaN             NaN
# 4         Radial Velocity                         NaN             NaN
#
#   right ascension   declination  host temperature  host mass  host radius
# 0    12h20m43.03s  +17d47m34.3s            4742.0       2.70        19.00
# 1    15h17m05.89s  +71d49m26.0s            4213.0       2.78        29.79
# 2    23h31m17.42s  +39d14m10.3s            4813.0       2.20        11.00
# 3    16h10m24.31s  +43d49m03.5s            5338.0       0.90         0.93
# 4    19h41m51.97s  +50d31m03.1s            5750.0       1.08         1.13

# %%
data.dtypes

# %%
data.info()

# %%
data.describe().T

# %%
data.describe(include = "object").T

# %%
data.isnull().value_counts().sum()

# %%
nulos = data.isnull().sum()

# %%
(data.isnull().sum()/data.shape[0])*100

# %%
data.head()

# %%
data.describe(include = "all").T.head(10)

# %%
data["solar system name"].unique()

# %%
data["stellar magnitude"].duplicated()

# %%
data["orbital radius"]

# %%
data["planet discovery method"].unique()

# %%
data["planet radius"]  ### AU is distance beetwen earth and the sun. 
                       ### AU = 149.597.870 Km

# %%
data["eccentricity"].unique()

# %%
data["row"].unique()

# %%
nulos = (data.isna().sum()/data.shape[0])*100
nulos

# %% [markdown]
# ##### After analize de data base i've notice that columns 'planet orbital inclination' and 'planet density' have 78% and 87% nulls data, probably the best option is delete this columns, not many information to extract.

# %%
data.drop((["planet orbital inclination" ,"planet density"]), axis = 1, inplace = True)

# %%
data.head()
# Out:
#    row                  name  light years from earth     planet mass  \
# 0    0  11 Comae Berenices b                   305.0   19.4 Jupiters
# 1    1    11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2    2       14 Andromedae b                   247.0    4.8 Jupiters
# 3    3         14 Herculis b                    59.0   4.66 Jupiters
# 4    4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar magnitude  discovery date planet type   planet radius  \
# 0              4.740            2007   Gas Giant  1.08 x Jupiter
# 1              5.016            2009   Gas Giant  1.09 x Jupiter
# 2              5.227            2008   Gas Giant  1.15 x Jupiter
# 3              6.610            2002   Gas Giant  1.15 x Jupiter
# 4              6.250            1996   Gas Giant   1.2 x Jupiter
#
#   orbital radius orbital period eccentricity solar system name  \
# 0        1.29 AU       326 days         0.23            11 Com
# 1        1.53 AU      1.4 years         0.08            11 UMi
# 2        0.83 AU     185.8 days            0            14 And
# 3        2.93 AU      4.9 years         0.37            14 Her
# 4        1.66 AU      2.2 years         0.68          16 Cyg B
#
#   planet discovery method right ascension   declination  host temperature  \
# 0         Radial Velocity    12h20m43.03s  +17d47m34.3s            4742.0
# 1         Radial Velocity    15h17m05.89s  +71d49m26.0s            4213.0
# 2         Radial Velocity    23h31m17.42s  +39d14m10.3s            4813.0
# 3         Radial Velocity    16h10m24.31s  +43d49m03.5s            5338.0
# 4         Radial Velocity    19h41m51.97s  +50d31m03.1s            5750.0
#
#    host mass  host radius
# 0       2.70        19.00
# 1       2.78        29.79
# 2       2.20        11.00
# 3       0.90         0.93
# 4       1.08         1.13

# %% [markdown]
# ###### Let´s start clean up the database.

# %%
nulos

# %%
data.describe().T

# %%
data.describe(include = "object").T

# %%
(data.isna().sum()/data.shape[0])*100

# %%
data["light years from earth"].median()

# %%
data["light years from earth"].mean()

# %% [markdown]
# ### there is a big difference between the mean and the median so i did the mean between them becouse i dont know wich one to choose.

# %%
data["light years from earth"].replace(np.nan,((data["light years from earth"].mean()+ data["light years from earth"].median())/2), inplace = True )

# %% [markdown]
# ### for stellar magnitude mean and median is really similar so i will use median

# %%
data["stellar magnitude"].replace(np.nan, data["stellar magnitude"].median(), inplace = True)

# %%
def eliminar_nulos(columna):
    media = columna.mean()
    mediana = columna.median()
    input(f"sustituir con la media o mediana?")
        if output == "media"
            return:
                   columna.replace(np.nan, columna.mean(), inplace = True)
        else:
            return:
                     columna.replace(np.nan, columna.median(), inplace = True)
# Out:
#   Cell In [82], line 5
#     if "media"
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ### For host temperature i will use the median too
# hacer una funcion para esto

# %%
data["host temperature (Cº)"].replace(np.nan, data["host temperature (Cº)"].median(), inplace = True)

# %%
data["host mass"].replace(np.nan, data["host mass"].median(), inplace = True)

# %%
data["host radius"].replace(np.nan, data["host radius"].median(), inplace = True)

# %%
data.isnull().sum()

# %%
data.dtypes

# %% [markdown]
# ##### The temperature is in Fareheid degrees i'm going to convert it in celsius degrees.  hay que restar los grados farenheit menos 32, multiplicarlo por 5 y dividirlo entre 9

# %%
data.rename(columns = {"host temperature" : "host temperature (Cº)"}, inplace = True)

# %%
data['host temperature (Cº)'] = data['host temperature (Cº)'].astype(int)

# %%
listaT = [] 
listaT
# Out:
# []

# %%
"""lev voy a restar Tº para que me de mas juego"""
for i in data['host temperature (Cº)']:
    i = ((i - 32)*5)/9 - 380
    listaT.append(i)

# %%
data['host temperature (Cº)'] = listaT

# %%
data.head()
# Out:
#    row                  name  light years from earth     planet mass  \
# 0    0  11 Comae Berenices b                   305.0   19.4 Jupiters
# 1    1    11 Ursae Minoris b                   410.0  14.74 Jupiters
# 2    2       14 Andromedae b                   247.0    4.8 Jupiters
# 3    3         14 Herculis b                    59.0   4.66 Jupiters
# 4    4          16 Cygni B b                    69.0   1.78 Jupiters
#
#    stellar magnitude  discovery date planet type   planet radius  \
# 0              4.740            2007   Gas Giant  1.08 x Jupiter
# 1              5.016            2009   Gas Giant  1.09 x Jupiter
# 2              5.227            2008   Gas Giant  1.15 x Jupiter
# 3              6.610            2002   Gas Giant  1.15 x Jupiter
# 4              6.250            1996   Gas Giant   1.2 x Jupiter
#
#   orbital radius orbital period eccentricity solar system name  \
# 0        1.29 AU       326 days         0.23            11 Com
# 1        1.53 AU      1.4 years         0.08            11 UMi
# 2        0.83 AU     185.8 days            0            14 And
# 3        2.93 AU      4.9 years         0.37            14 Her
# 4        1.66 AU      2.2 years         0.68          16 Cyg B
#
#   planet discovery method right ascension   declination  \
# 0         Radial Velocity    12h20m43.03s  +17d47m34.3s
# 1         Radial Velocity    15h17m05.89s  +71d49m26.0s
# 2         Radial Velocity    23h31m17.42s  +39d14m10.3s
# 3         Radial Velocity    16h10m24.31s  +43d49m03.5s
# 4         Radial Velocity    19h41m51.97s  +50d31m03.1s
#
#    host temperature (Cº)  host mass  host radius
# 0            2236.666667       2.70        19.00
# 1            1942.777778       2.78        29.79
# 2            2276.111111       2.20        11.00
# 3            2567.777778       0.90         0.93
# 4            2796.666667       1.08         1.13

# %% [markdown]
# ### lets divide planets by temperature type( cold, hot, very hot)

# %%
Ttype = []

# %%
data["host temperature (Cº)"].describe()
# Out:
# count     4284.000000
# mean      2649.132690
# std        937.515543
# min        -78.333333
# 25%       2414.583333
# 50%       2706.666667
# 75%       2880.000000
# max      31268.888889
# Name: host temperature (Cº), dtype: float64

# %%
for i in data["host temperature (Cº)"]:
    if i <= 10:
        Ttype.append("frío")
    if i > 10 and i <= 150:
        Ttype.append("caliente")
    if i > 151:
        Ttype.append("muy caliente")

# %%
data["Tª type"] = Ttype

# %%
data.head()

# %% [markdown]
# ### lets do something similar with "light years from earth"

# %%
data["light years from earth"].describe().T

# %%
Dtype = []

# %%
for i in data["light years from earth"]:
    if i <= 25:
        Dtype.append("cerca")
    if i >= 25 and i <= 500:
        Dtype.append("lejos")
    if i >= 501:
        Dtype.append("criogenia")

# %%
len(Dtype)
# Out:
# 4284

# %%
data["light years from earth"].size
# Out:
# 4284

# %%
data["distance type"] = Dtype

# %%
data.head()

# %% [markdown]
# ### ahora hare conversiones, en vez de compararlo con Jupiter lo comparare con la Tierra

# %%
"""Para planet mass:
un jupiter_mass = 1.898 * 10 ** 27 kg
Tierra_mass = 5.972 * 10 ** 24 kg

Para planet radius:
jupyter_radius = 69.911 km
Tierra_radius = 6.371 km
"""

# %%
data1 = data

# %%
data1["planet radius"].info()

# %%
listaPlanet = data1["planet radius"].str.split(" ")[:][0]

# %%
listaPlanet[:]
# Out:
# ['1.08', 'x', 'Jupiter']

# %%
def limpiar_radio(i):
    return i.split()[0]

# %%
data1["planet radius [0]"] = data1["planet radius"].apply(limpiar_radio)

# %%
data1.sample(10)
# Out:
#        row                   name  light years from earth     planet mass  \
# 1566  1566          Kepler-1107 b                  1491.0     2.36 Earths
# 3927  3927  OGLE-2012-BLG-0838L b                 20616.0  0.167 Jupiters
# 1494  1494          Kepler-1056 b                  3167.0     9.32 Earths
# 935    935             HD 90156 b                    72.0    17.98 Earths
# 1037  1037               K2-116 b                   161.0    0.257 Earths
# 649    649            HD 197037 b                   108.0   0.79 Jupiters
# 2690  2690           Kepler-290 c                  2311.0     7.75 Earths
# 1042  1042                K2-11 b                  1084.0   0.14 Jupiters
# 3099  3099           Kepler-476 b                  2241.0     9.69 Earths
# 2370  2370           Kepler-179 c                  2011.0     4.66 Earths
#
#       stellar magnitude  discovery date   planet type    planet radius  \
# 1566             14.128            2016   Super Earth     1.34 x Earth
# 3927             13.563            2020     Gas Giant  0.748 x Jupiter
# 1494             14.560            2016  Neptune-like  0.269 x Jupiter
# 935               6.920            2009  Neptune-like  0.395 x Jupiter
# 1037             10.910            2017   Terrestrial     0.69 x Earth
# 649               6.809            2012     Gas Giant   1.24 x Jupiter
# 2690             15.565            2014  Neptune-like  0.241 x Jupiter
# 1042             13.386            2015     Gas Giant  0.674 x Jupiter
# 3099             13.860            2016  Neptune-like  0.275 x Jupiter
# 2370             14.603            2014   Super Earth      2.0 x Earth
#
#      orbital radius orbital period eccentricity    solar system name  \
# 1566        Unknown       0.6 days            0           Kepler-110
# 3927        4.43 AU     14.8 years            0  OGLE-2012-BLG-0838L
# 1494        Unknown      27.5 days            0          Kepler-1052
# 935         0.25 AU      49.8 days         0.31             HD 90156
# 1037       0.048 AU       4.7 days         0.06               K2-115
# 649         2.07 AU      2.8 years         0.22            HD 197037
# 2690       0.205 AU      36.8 days            0            Kepler-29
# 1042      0.2257 AU      39.9 days            0               K2-119
# 3099        Unknown        14 days            0           Kepler-472
# 2370       0.064 AU       6.4 days            0           Kepler-179
#
#      planet discovery method right ascension   declination  \
# 1566                 Transit    19h31m42.99s  +48d36m10.1s
# 3927            Microlensing    18h12m00.74s  -25d42m41.8s
# 1494                 Transit    19h41m22.26s  +46d36m08.2s
# 935          Radial Velocity    10h23m55.28s  -29d38m43.9s
# 1037                 Transit    08h26m12.83s  +12d16m55.0s
# 649          Radial Velocity    20h39m32.96s  +42d14m54.8s
# 2690                 Transit    19h53m23.60s  +47d29m28.4s
# 1042                 Transit    08h48m02.34s  +16d54m06.7s
# 3099                 Transit    19h46m05.83s  +39d14m59.2s
# 2370                 Transit    19h54m39.30s  +47d45m43.4s
#
#       host temperature (Cº)  host mass  host radius       Tª type  \
# 1566            2913.333333       0.96         1.15  muy caliente
# 3927            2706.666667       0.40         0.97  muy caliente
# 1494            2873.333333       1.03         1.03  muy caliente
# 935             2712.777778       0.84         0.97  muy caliente
# 1037            2745.000000       0.95         0.88  muy caliente
# 649             3018.888889       1.11         0.97  muy caliente
# 2690            2590.000000       0.76         0.73  muy caliente
# 1042            2235.555556       0.76         0.71  muy caliente
# 3099            2377.777778       0.85         0.78  muy caliente
# 2370            2547.777778       0.96         0.76  muy caliente
#
#      distance type planet radius [0]
# 1566     criogenia              1.34
# 3927     criogenia             0.748
# 1494     criogenia             0.269
# 935          lejos             0.395
# 1037         lejos              0.69
# 649          lejos              1.24
# 2690     criogenia             0.241
# 1042     criogenia             0.674
# 3099     criogenia             0.275
# 2370     criogenia               2.0

# %%
"Kepler-238" in data["name"]

# %%
data["planet discovery method"].unique()

# %% [markdown]
# ### voy a seleccionar solo los planetas kepler-

# %%
data1["name"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4284 entries, 0 to 4283
# Series name: name
# Non-Null Count  Dtype
# --------------  -----
# 4284 non-null   object
# dtypes: object(1)
# memory usage: 33.6+ KB

# %%
df_keplers = data1[data1["name"].str.contains(pat = "Kepler", regex = True)]

# %%
df_keplers
# Out:
#        row           name  light years from earth       planet mass  \
# 1419  1419  Kepler-1000 b                  3017.0       20.3 Earths
# 1420  1420  Kepler-1001 b                  3291.0       10.1 Earths
# 1421  1421  Kepler-1001 c                  3291.0       3.11 Earths
# 1422  1422  Kepler-1002 b                  1386.0       3.57 Earths
# 1423  1423  Kepler-1003 b                  2848.0       3.82 Earths
# ...    ...            ...                     ...               ...
# 3790  3790   Kepler-999 b                  1853.0       6.08 Earths
# 3791  3791    Kepler-99 b                   684.0       6.15 Earths
# 3792  3792     Kepler-9 b                  2003.0  0.13655 Jupiters
# 3793  3793     Kepler-9 c                  2003.0       29.9 Earths
# 3794  3794     Kepler-9 d                  2003.0       3.33 Earths
#
#       stellar magnitude  discovery date   planet type    planet radius  \
# 1419             13.192            2016  Neptune-like  0.425 x Jupiter
# 1420             15.330            2016  Neptune-like  0.281 x Jupiter
# 1421             15.330            2020   Super Earth    1.578 x Earth
# 1422             11.647            2016   Super Earth     1.71 x Earth
# 1423             14.023            2016   Super Earth     1.78 x Earth
# ...                 ...             ...           ...              ...
# 3790             12.234            2016  Neptune-like  0.209 x Jupiter
# 3791             12.962            2014   Super Earth     1.48 x Earth
# 3792             13.781            2010     Gas Giant   0.74 x Jupiter
# 3793             13.781            2010  Neptune-like  0.721 x Jupiter
# 3794             13.781            2010   Super Earth     1.64 x Earth
#
#      orbital radius orbital period eccentricity solar system name  \
# 1419        Unknown       120 days            0         Kepler-10
# 1420        Unknown      14.3 days            0         Kepler-10
# 1421        Unknown       9.2 days            0        Kepler-100
# 1422        Unknown       4.3 days            0        Kepler-100
# 1423        Unknown       3.6 days            0        Kepler-100
# ...             ...            ...          ...               ...
# 3790        Unknown         6 days            0      KIC 10001893
# 3791        Unknown       4.6 days            0      KIC 10525077
# 3792       0.143 AU      19.2 days         0.06       KIC 3558849
# 3793       0.227 AU        39 days         0.07       KIC 5095269
# 3794      0.0273 AU       1.6 days            0       KIC 5437945
#
#             planet discovery method right ascension   declination  \
# 1419                        Transit    19h02m43.05s  +50d14m28.7s
# 1420                        Transit    19h02m43.05s  +50d14m28.7s
# 1421                        Transit    19h25m32.63s  +41d59m25.0s
# 1422                        Transit    19h25m32.63s  +41d59m25.0s
# 1423                        Transit    19h25m32.63s  +41d59m25.0s
# ...                             ...             ...           ...
# 3790  Orbital Brightness Modulation    19h09m33.41s  +46d59m04.2s
# 3791                        Transit    19h09m30.74s  +47d46m16.3s
# 3792                        Transit    19h39m47.96s  +38d36m18.7s
# 3793      Eclipse Timing Variations    19h22m12.47s  +40d14m06.1s
# 3794                        Transit    19h13m53.97s  +40d39m04.9s
#
#       host temperature (Cº)  host mass  host radius       Tª type  \
# 1419            2773.333333       0.91         1.06  muy caliente
# 1420            2773.333333       0.91         1.06  muy caliente
# 1421            2838.333333       1.08         1.49  muy caliente
# 1422            2838.333333       1.08         1.49  muy caliente
# 1423            2838.333333       1.08         1.49  muy caliente
# ...                     ...        ...          ...           ...
# 3790           14880.000000       0.96         0.97  muy caliente
# 3791            2986.111111       1.01         1.01  muy caliente
# 3792            3032.777778       0.98         1.01  muy caliente
# 3793            2706.666667       1.21         0.97  muy caliente
# 3794            3124.444444       1.07         1.24  muy caliente
#
#      distance type planet radius [0]
# 1419     criogenia             0.425
# 1420     criogenia             0.281
# 1421     criogenia             1.578
# 1422     criogenia              1.71
# 1423     criogenia              1.78
# ...            ...               ...
# 3790     criogenia             0.209
# 3791     criogenia              1.48
# 3792     criogenia              0.74
# 3793     criogenia             0.721
# 3794     criogenia              1.64
#
# [2376 rows x 21 columns]

# %%
df_keplers.reset_index(inplace = True)

# %% [markdown]
# ### data frame complementaria

# %%
data_compl = pd.read_csv("cumulative_2023.01.11_04.18.35.csv",  skiprows=22)
data_compl.head()
# Out:
#    loc_rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0          1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1          2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2          3  10811496  K00753.01           NaN       CANDIDATE
# 3          4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4          5  10854555  K00755.01  Kepler-664 b       CONFIRMED
#
#   koi_pdisposition  koi_score  koi_impact  koi_impact_err1  koi_impact_err2  \
# 0        CANDIDATE      1.000       0.146            0.318           -0.146
# 1        CANDIDATE      0.969       0.586            0.059           -0.443
# 2        CANDIDATE      0.000       0.969            5.126           -0.077
# 3   FALSE POSITIVE      0.000       1.276            0.115           -0.092
# 4        CANDIDATE      1.000       0.701            0.235           -0.478
#
#    koi_prad  koi_prad_err1  koi_prad_err2  koi_teq  koi_teq_err1  \
# 0      2.26           0.26          -0.15    793.0           NaN
# 1      2.83           0.32          -0.19    443.0           NaN
# 2     14.60           3.92          -1.31    638.0           NaN
# 3     33.46           8.50          -2.83   1395.0           NaN
# 4      2.75           0.88          -0.35   1406.0           NaN
#
#    koi_teq_err2  koi_kepmag
# 0           NaN      15.347
# 1           NaN      15.347
# 2           NaN      15.436
# 3           NaN      15.597
# 4           NaN      15.509

# %%
data_compl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   kepid             9564 non-null   int64
#  1   kepoi_name        9564 non-null   object
#  2   name              2673 non-null   object
#  3   koi_disposition   9564 non-null   object
#  4   koi_pdisposition  9564 non-null   object
#  5   koi_score         8054 non-null   float64
#  6   koi_impact        9201 non-null   float64
#  7   koi_impact_err1   9110 non-null   float64
#  8   koi_impact_err2   9110 non-null   float64
#  9   koi_prad          9201 non-null   float64
#  10  koi_prad_err1     9201 non-null   float64
#  11  koi_prad_err2     9201 non-null   float64
#  12  koi_teq           9201 non-null   float64
#  13  koi_teq_err1      0 non-null      float64
#  14  koi_teq_err2      0 non-null      float64
#  15  koi_kepmag        9563 non-null   float64
# dtypes: float64(11), int64(1), object(4)
# memory usage: 1.2+ MB

# %%
def eliminar_columnas(df, columna):
    return df.drop( columna, axis=1, inplace = True)

# %%
eliminar_columnas(data_compl,["koi_kepmag"])

# %%
data_compl.head()
# Out:
#       kepid          name  koi_impact  koi_prad
# 0  10797460  Kepler-227 b       0.146      2.26
# 1  10797460  Kepler-227 c       0.586      2.83
# 2  10811496           NaN       0.969     14.60
# 3  10848459           NaN       1.276     33.46
# 4  10854555  Kepler-664 b       0.701      2.75

# %%
data_compl.to_csv("complementario.csv")

# %% [markdown]
# ### voy a juntar las 2 tablas

# %%
data_compl.rename({"kepler_name" : "name"},axis = 1, inplace = True)

# %%
def_keplers = df_keplers.merge(data_compl,how = "inner", on = "name")

# %%
def_keplers.sample(10)
# Out:
#       index   row           name  light years from earth     planet mass  \
# 257    1676  1676  Kepler-1195 b                  2649.0     4.98 Earths
# 581    2000  2000  Kepler-1439 b                   701.0     2.73 Earths
# 89     1508  1508  Kepler-1067 b                  2248.0    0.437 Earths
# 1220   2649  2649   Kepler-276 b                  3855.0      8.6 Earths
# 753    2173  2173   Kepler-156 b                  1465.0      5.9 Earths
# 1100   2528  2528   Kepler-235 b                  1413.0      5.6 Earths
# 2221   3684  3684   Kepler-913 b                  1947.0      4.9 Earths
# 642    2061  2061  Kepler-1488 b                  2016.0     4.12 Earths
# 145    1564  1564  Kepler-1105 b                  1204.0      4.7 Earths
# 2240   3703  3703    Kepler-92 b                  1581.0  0.202 Jupiters
#
#       stellar magnitude  discovery date   planet type    planet radius  \
# 257              15.912            2016   Super Earth     2.08 x Earth
# 581              16.098            2016   Super Earth     1.46 x Earth
# 89               14.273            2016   Terrestrial      0.8 x Earth
# 1220             15.365            2014  Neptune-like  0.256 x Jupiter
# 753              14.156            2014  Neptune-like  0.205 x Jupiter
# 1100             15.969            2014  Neptune-like     2.23 x Earth
# 2221             15.739            2016   Super Earth     2.06 x Earth
# 642              13.077            2016   Super Earth     1.86 x Earth
# 145              15.142            2016   Super Earth     2.01 x Earth
# 2240             11.745            2013     Gas Giant  0.313 x Jupiter
#
#      orbital radius orbital period eccentricity solar system name  \
# 257         Unknown       8.5 days            0       Kepler-1189
# 581         Unknown       8.1 days            0       Kepler-1436
# 89          Unknown       0.8 days            0       Kepler-1062
# 1220       0.119 AU      14.1 days            0        Kepler-275
# 753        0.054 AU         5 days            0       Kepler-1567
# 1100       0.037 AU       3.3 days            0        Kepler-233
# 2221        Unknown      10.3 days            0        Kepler-916
# 642         Unknown      39.8 days            0       Kepler-1484
# 145         Unknown       4.4 days            0         Kepler-11
# 2240        Unknown      13.7 days         0.17         Kepler-93
#
#      planet discovery method right ascension   declination  \
# 257                  Transit    19h53m42.32s  +47d56m48.4s
# 581                  Transit    19h50m50.78s  +46d46m04.9s
# 89                   Transit    18h55m35.86s  +41d13m17.8s
# 1220                 Transit    19h29m55.13s  +38d30m53.7s
# 753                  Transit    19h06m46.85s  +40d17m30.5s
# 1100                 Transit    19h45m27.97s  +51d19m10.3s
# 2221                 Transit    19h23m56.00s  +45d58m23.9s
# 642                  Transit    19h30m44.23s  +38d07m34.6s
# 145                  Transit    19h48m27.63s  +41d54m32.9s
# 2240         Radial Velocity    19h25m40.39s  +38d40m20.5s
#
#       host temperature (Cº)  host mass  host radius       Tª type  \
# 257             2942.222222       1.11         1.16  muy caliente
# 581             2920.000000       1.06         1.09  muy caliente
# 89              2156.111111       0.75         0.70  muy caliente
# 1220            3027.222222       0.96         1.38  muy caliente
# 753             2743.888889       0.95         0.93  muy caliente
# 1100            2580.000000       0.96         0.76  muy caliente
# 2221            2517.777778       0.85         0.81  muy caliente
# 642             2785.555556       0.94         0.92  muy caliente
# 145             2748.333333       0.96         1.06  muy caliente
# 2240            2751.666667       1.09         0.98  muy caliente
#
#      distance type planet radius [0]     kepid  koi_impact  koi_prad
# 257      criogenia              2.08   5599774       0.628      2.14
# 581      criogenia              1.46   5688790       0.928      1.59
# 89       criogenia               0.8   8804845       0.399      0.75
# 1220     criogenia             0.256   3962243       0.811      2.73
# 753      criogenia             0.205   2438264       0.817      2.46
# 1100     criogenia              2.23   4139816       0.466      2.03
# 2221     criogenia              2.06   6543893       0.298      5.75
# 642      criogenia              1.86  11754430       0.600      2.23
# 145      criogenia              2.01   6921944       0.869      2.19
# 2240     criogenia             0.313   6196457       0.658      3.63

# %%
def_keplers.shape
# Out:
# (2329, 38)

# %%
def_keplers.to_csv("keplers.csv")

# %% [markdown]
# ### Voy a escrapear las imagenes de los planetas

# %%
#!pip install selenium
#!pip install webdriver-manager

# %%
from time import sleep
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options




import warnings
warnings.filterwarnings('ignore')

# %%
import requests
from bs4 import BeautifulSoup

# %%
opciones= Options()
opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
#para ocultarme como robot
opciones.add_experimental_option('useAutomationExtension', False)
opciones.add_argument('--start-maximized') #empezar maximizado
opciones.add_argument('user.data-dir=selenium') #guarda las cookies
#.add_argument('--incognito')#incognito window

# %%
#scraping = {"name" : [],"photo" : [], "description" : [], "discovery date" : []}

# %%
scraping.pop("photo")
# Out:
# []

# %%
planetas = def_keplers["name"]

# %%
# %%time
planetas = def_keplers["name"]
#scraping = {"name" : [],"photo" : [], "description" : [], "discovery date" : []}

for planeta in planetas:
    if planeta not in scraping["name"]:
        driver = webdriver.Chrome(ChromeDriverManager().install())
        driver.get("https://exoplanets.nasa.gov/exep/search.html?q=")
        driver.implicitly_wait(5)
        driver.find_element("css selector", "#gsc-i-id1").click()
        driver.find_element("css selector", "#gsc-i-id1").send_keys(f"{planeta}", Keys.TAB)
        driver.find_element("css selector", "#___gcse_0 > div > div > form > table > tbody > tr > td.gsc-search-button").click()
        ##no en todos es el primer resultado

        try:
                driver.find_element("css selector", "#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div > div > div.gsc-expansionArea > div:nth-child(1) > div.gs-webResult.gs-result > div.gsc-thumbnail-inside > div > a").click()

                #dentro del planeta
                scraping["description"].append(driver.find_element("css selector", "#primary_column > div.wysiwyg_content > p").text)
                scraping["discovery date"].append(driver.find_element("css selector", "#secondary_column > table > tbody > tr:nth-child(1) > td:nth-child(2) > div.value").text)
                scraping["name"].append(planeta)
        except:
                driver.back() #vuelve a la pagina anterior
                driver.find_element("css selector", "#gsc-i-id1").click()
                driver.find_element("css selector", "#gsc-i-id1").send_keys(f"{planeta}", Keys.TAB)
                driver.find_element("css selector", "#___gcse_0 > div > div > form > table > tbody > tr > td.gsc-search-button").click()
                driver.find_element("css selector", "#___gcse_0 > div > div > div > div.gsc-wrapper > div.gsc-resultsbox-visible > div > div > div.gsc-expansionArea > div:nth-child(2) > div.gs-webResult.gs-result > div.gsc-thumbnail-inside > div > a").click()

            #dentro del planeta
                
                scraping["description"].append(driver.find_element("css selector", "#primary_column > div.wysiwyg_content > p").text)
                scraping["discovery date"].append(driver.find_element("css selector", "#secondary_column > table > tbody > tr:nth-child(1) > td:nth-child(2) > div.value").text)
                scraping["name"].append(planeta)
    else:
        pass
# Out:
# CPU times: total: 15.6 ms
# Wall time: 75.7 ms

# %%
print(len(scraping["name"]),len(scraping["description"]), len(scraping["discovery date"]))
# Out:
# 2329 2329 2329

# %%
df_scraping= pd.DataFrame(scraping)

# %%
df_scraping.to_csv("scraping.csv")

# %%
df_scraping.head()
# Out:
#             name                                        description  \
# 0  Kepler-1000 b  Kepler-1000 b is a Neptune-like exoplanet that...
# 1  Kepler-1001 b  Kepler-1001 b is a Neptune-like exoplanet that...
# 2  Kepler-1001 c  Kepler-1001 b is a Neptune-like exoplanet that...
# 3  Kepler-1002 b  Kepler-1002 b is a super Earth exoplanet that ...
# 4  Kepler-1003 b  Kepler-1003 b is a super Earth exoplanet that ...
#
#   discovery date
# 0           2016
# 1           2016
# 2           2016
# 3           2016
# 4           2016

# %%
scraping["description"][0]
# Out:
# 'Kepler-1000 b is a Neptune-like exoplanet that orbits an F-type star. Its mass is 20.3 Earths, it takes 120 days to complete one orbit of its star, and is 0.5337 AU from its star. Its discovery was announced in 2016.'

# %% [markdown]
# ### añado la tercera tabla

# %%
definitiva = def_keplers.merge(df_scraping,how = "inner", on = "name")

# %%
definitiva.head()
# Out:
#    index   row           name  light years from earth  planet mass  \
# 0   1419  1419  Kepler-1000 b                  3017.0  20.3 Earths
# 1   1420  1420  Kepler-1001 b                  3291.0  10.1 Earths
# 2   1421  1421  Kepler-1001 c                  3291.0  3.11 Earths
# 3   1422  1422  Kepler-1002 b                  1386.0  3.57 Earths
# 4   1423  1423  Kepler-1003 b                  2848.0  3.82 Earths
#
#    stellar magnitude  discovery date_x   planet type    planet radius  \
# 0             13.192              2016  Neptune-like  0.425 x Jupiter
# 1             15.330              2016  Neptune-like  0.281 x Jupiter
# 2             15.330              2020   Super Earth    1.578 x Earth
# 3             11.647              2016   Super Earth     1.71 x Earth
# 4             14.023              2016   Super Earth     1.78 x Earth
#
#   orbital radius orbital period eccentricity solar system name  \
# 0        Unknown       120 days            0         Kepler-10
# 1        Unknown      14.3 days            0         Kepler-10
# 2        Unknown       9.2 days            0        Kepler-100
# 3        Unknown       4.3 days            0        Kepler-100
# 4        Unknown       3.6 days            0        Kepler-100
#
#   planet discovery method right ascension   declination  \
# 0                 Transit    19h02m43.05s  +50d14m28.7s
# 1                 Transit    19h02m43.05s  +50d14m28.7s
# 2                 Transit    19h25m32.63s  +41d59m25.0s
# 3                 Transit    19h25m32.63s  +41d59m25.0s
# 4                 Transit    19h25m32.63s  +41d59m25.0s
#
#    host temperature (Cº)  host mass  host radius       Tª type distance type  \
# 0            2773.333333       0.91         1.06  muy caliente     criogenia
# 1            2773.333333       0.91         1.06  muy caliente     criogenia
# 2            2838.333333       1.08         1.49  muy caliente     criogenia
# 3            2838.333333       1.08         1.49  muy caliente     criogenia
# 4            2838.333333       1.08         1.49  muy caliente     criogenia
#
#   planet radius [0]     kepid  koi_impact  koi_prad  \
# 0             0.425  10063802       0.580      4.54
# 1             0.281  11074178       0.924      3.05
# 2             1.578  11074178       0.971      2.17
# 3              1.71   7449136       0.641      1.75
# 4              1.78   8689793       0.331      1.29
#
#                                          description discovery date_y
# 0  Kepler-1000 b is a Neptune-like exoplanet that...             2016
# 1  Kepler-1001 b is a Neptune-like exoplanet that...             2016
# 2  Kepler-1001 b is a Neptune-like exoplanet that...             2016
# 3  Kepler-1002 b is a super Earth exoplanet that ...             2016
# 4  Kepler-1003 b is a super Earth exoplanet that ...             2016

# %%
definitiva.to_csv("definitivo.csv")
